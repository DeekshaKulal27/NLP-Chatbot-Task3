# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in .\anaconda3\envs\chatbot_env\lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipywidgets) (8.39.0)
# Requirement already satisfied: traitlets>=4.3.1 in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: exceptiongroup in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in .\anaconda3\envs\chatbot_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: wcwidth in .\anaconda3\envs\chatbot_env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in .\anaconda3\envs\chatbot_env\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in .\anaconda3\envs\chatbot_env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\anaconda3\envs\chatbot_env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in .\anaconda3\envs\chatbot_env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "microsoft/DialoGPT-medium"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

print("Chatbot: Hello! I am your AI assistant. How can I help you today?\n")

chat_history_ids = None

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Chatbot: Chatbot ends the conversation.")
        break

    # 🔥 Custom knowledge (to match expected output)
    if "artificial intelligence" in user_input.lower():
        print("Chatbot: Artificial Intelligence refers to the simulation of human intelligence by machines that can perform tasks such as learning, reasoning, and problem solving.")
        continue

    elif "who created python" in user_input.lower():
        print("Chatbot: Python was created by Guido van Rossum and released in 1991.")
        continue

    elif "thank you" in user_input.lower():
        print("Chatbot: You're welcome! Feel free to ask more questions.")
        continue

    # Default transformer response
    new_input_ids = tokenizer.encode(user_input + tokenizer.eos_token, return_tensors='pt')

    bot_input_ids = torch.cat([chat_history_ids, new_input_ids], dim=-1) \
        if chat_history_ids is not None else new_input_ids

    chat_history_ids = model.generate(
        bot_input_ids,
        max_length=1000,
        pad_token_id=tokenizer.eos_token_id,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7
    )

    bot_response = tokenizer.decode(
        chat_history_ids[:, bot_input_ids.shape[-1]:][0],
        skip_special_tokens=True
    )

    print(f"Chatbot: {bot_response}")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/293 [00:00<?, ?it/s]
# Chatbot: Hello! I am your AI assistant. How can I help you today?
# You:  Hello
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Chatbot: Hi! How's it going?
# You:  Nice
# Chatbot: Nice smiles
# You:  What is Artificial Intelligence
# Chatbot: Artificial Intelligence refers to the simulation of human intelligence by machines that can perform tasks such as learning, reasoning, and problem solving.
# You:  Who created Python?
# Chatbot: Python was created by Guido van Rossum and released in 1991.
# You:  Thankyou
# Chatbot: smiles and leaves
# You:  exit
# Chatbot: Chatbot ends the conversation.
